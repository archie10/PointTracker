# %%
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
#def get_frames(video_path):
video_path = '/home/saklani/Projects/PointTracker/video/m3v1mp4.mp4'
image = cv2.VideoCapture(video_path)
ret, frame = image.read()

# %%
frame
# Out:
# array([[[ 15,  15,  15],
#         [ 10,  10,  10],
#         [168, 168, 168],
#         ...,
#         [ 80,  80,  80],
#         [ 80,  80,  80],
#         [ 80,  80,  80]],
#
#        [[ 70,  70,  70],
#         [ 70,  70,  70],
#         [ 71,  71,  71],
#         ...,
#         [ 82,  82,  82],
#         [ 80,  80,  80],
#         [ 80,  80,  80]],
#
#        [[ 69,  69,  69],
#         [ 70,  70,  70],
#         [ 70,  70,  70],
#         ...,
#         [ 82,  82,  82],
#         [ 82,  82,  82],
#         [ 80,  80,  80]],
#
#        ...,
#
#        [[ 30,  30,  30],
#         [ 33,  33,  33],
#         [ 41,  41,  41],
#         ...,
#         [ 51,  51,  51],
#         [ 51,  51,  51],
#         [ 51,  51,  51]],
#
#        [[ 34,  34,  34],
#         [ 38,  38,  38],
#         [ 44,  44,  44],
#         ...,
#         [ 50,  50,  50],
#         [ 50,  50,  50],
#         [ 50,  50,  50]],
#
#        [[ 38,  38,  38],
#         [ 43,  43,  43],
#         [ 48,  48,  48],
#         ...,
#         [ 50,  50,  50],
#         [ 50,  50,  50],
#         [ 50,  50,  50]]], dtype=uint8)

# %%
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
plt.show()
